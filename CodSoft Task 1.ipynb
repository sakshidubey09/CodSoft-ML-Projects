# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.svm import LinearSVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

# %%
# Read training data
train_data = pd.read_csv("train_data.txt", sep=':::', names=['ID', 'TITLE', 'GENRE', 'DESCRIPTION'])
display(train_data.head())
print(train_data.shape)

# Read test data
test_data = pd.read_csv("test_data.txt", sep=':::', names=['ID', 'TITLE', 'GENRE', 'DESCRIPTION'])
display(test_data.head())
print(test_data.shape)

# Read test solution data
test_solution_data = pd.read_csv("test_data_solution.txt", sep=':::', names=['ID', 'TITLE', 'GENRE', 'DESCRIPTION'])
display(test_solution_data.head())
print(test_solution_data.shape)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6320\804326263.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   train_data = pd.read_csv("train_data.txt", sep=':::', names=['ID', 'TITLE', 'GENRE', 'DESCRIPTION'])
#    ID                               TITLE       GENRE  \
# 0   1       Oscar et la dame rose (2009)       drama
# 1   2                       Cupid (1997)    thriller
# 2   3   Young, Wild and Wonderful (1980)       adult
# 3   4              The Secret Sin (1915)       drama
# 4   5             The Unrecovered (2007)       drama
#
#                                          DESCRIPTION
# 0   Listening in to a conversation between his do...
# 1   A brother and sister with a past incestuous r...
# 2   As the bus empties the students for their fie...
# ...

# %%
pip install matplotlib seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=train_data, x='GENRE')
plt.title('Count of Genres in Training Data')
plt.xlabel('Genre')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
plt.figure(figsize=(10, 8))
genre_corr = train_data.groupby(['GENRE', 'GENRE']).size().unstack()

# Convert values to integers or use the fill_value parameter
sns.heatmap(genre_corr, cmap='coolwarm', annot=True, fmt='g', cbar_kws={'label': 'Count'})
plt.title('Heatmap of Genre Correlation in Training Data')
plt.show()

# %%
sns.pairplot(train_data[['TITLE_LENGTH']], diag_kind='kde')
plt.suptitle('Pairplot of Numeric Features', y=1.02)
plt.show()

# %%
# Handling missing values
train_data['DESCRIPTION'].fillna("", inplace=True)
test_data['DESCRIPTION'].fillna("", inplace=True)

t_v = TfidfVectorizer(stop_words='english', max_features=100000)
X_train = t_v.fit_transform(train_data['DESCRIPTION'])
X_test = t_v.transform(test_data['DESCRIPTION'])

label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(train_data['GENRE'])
y_test = label_encoder.transform(test_solution_data['GENRE'])

# %%
X_train_sub, X_val, y_train_sub, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

clf = LinearSVC()
clf.fit(X_train_sub, y_train_sub)

y_val_pred = clf.predict(X_val)
print("Validation Accuracy:", accuracy_score(y_val, y_val_pred))
print("Validation Classification Report:\n", classification_report(y_val, y_val_pred))
# Out:
# Validation Accuracy: 0.5836945494789265
# Validation Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.44      0.32      0.37       263
#            1       0.74      0.44      0.55       112
#            2       0.45      0.21      0.28       139
#            3       0.47      0.15      0.23       104
#            4       0.00      0.00      0.00        61
#            5       0.53      0.59      0.56      1443
#            6       0.39      0.07      0.11       107
#            7       0.69      0.81      0.75      2659
#            8       0.56      0.72      0.63      2697
#            9       0.36      0.17      0.23       150
#           10       0.13      0.03      0.04        74
#           11       0.82      0.68      0.74        40
#           12       0.00      0.00      0.00        45
#           13       0.65      0.66      0.66       431
#           14       0.61      0.53      0.57       144
# ...

# %%
y_pred = clf.predict(X_test)
print("Test Accuracy:", accuracy_score(y_test, y_pred))
print("Test Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Test Accuracy: 0.09357933579335793
# Test Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      1314
#            1       0.00      0.00      0.00       590
#            2       0.00      0.00      0.00       775
#            3       0.00      0.00      0.00       498
#            4       0.00      0.00      0.00       264
#            5       0.00      0.00      0.00      7446
#            6       0.00      0.00      0.00       505
#            7       0.00      0.00      0.00     13096
#            8       0.00      0.00      0.00     13612
#            9       0.00      0.00      0.00       783
#           10       0.00      0.00      0.00       322
#           11       0.00      0.00      0.00       193
#           12       0.00      0.00      0.00       243
#           13       0.00      0.00      0.00      2204
#           14       0.00      0.00      0.00       731
# ...

# %%
from sklearn.naive_bayes import MultinomialNB
Mnb_classifier = MultinomialNB()
Mnb_classifier.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
predictions = Mnb_classifier.predict(X_test)
print(predictions)
# Out:
# [8 8 8 ... 8 8 8]

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, predictions)
print(f'Accuracy: {accuracy:.2%}')
# Out:
# Accuracy: 25.11%

# %%
from sklearn.metrics import classification_report
print('\nClassification Report:')
print(classification_report(y_test, predictions))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      1314
#            1       0.00      0.00      0.00       590
#            2       0.00      0.00      0.00       775
#            3       0.00      0.00      0.00       498
#            4       0.00      0.00      0.00       264
#            5       0.00      0.00      0.00      7446
#            6       0.00      0.00      0.00       505
#            7       0.00      0.00      0.00     13096
#            8       0.25      1.00      0.40     13612
#            9       0.00      0.00      0.00       783
#           10       0.00      0.00      0.00       322
#           11       0.00      0.00      0.00       193
#           12       0.00      0.00      0.00       243
#           13       0.00      0.00      0.00      2204
#           14       0.00      0.00      0.00       731
#           15       0.00      0.00      0.00       276
# ...

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(Mnb_classifier, X_train, y_train, cv=5)
print(f'Cross-Validation Accuracy: {scores.mean():.2%} +/- {scores.std():.2%}')
# Out:
# Cross-Validation Accuracy: 44.44% +/- 0.15%

# %%
def predict_movie(description):
    t_v1 = t_v.transform([description])
    pred_label = clf.predict(t_v1)
    return label_encoder.inverse_transform(pred_label)[0]

sample_descr_for_movie = "A movie where girl falls in love with a boy"
print(predict_movie(sample_descr_for_movie))

sample_descr_for_movie1 = "A movie where people are left alone in a boat"
print(predict_movie(sample_descr_for_movie1))
# Out:
#  drama
#  adventure
